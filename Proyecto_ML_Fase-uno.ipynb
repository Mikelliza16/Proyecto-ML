# %% [markdown]
# url: https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# --- PASO 1: Limpieza de Datos ---
# Las columnas 'id' y 'Unnamed: 0' son identificadores, no variables.
# Calcular su correlación no tiene sentido y ensucia el gráfico.
# Las eliminamos temporalmente para el gráfico.
columns_to_drop = ['Unnamed: 0', 'id']
df_clean = df.drop(columns=columns_to_drop, errors='ignore')

# Calculamos la matriz de correlación sobre los datos limpios
corr_matrix = df_clean.corr(numeric_only=True)


# --- PASO 2: Configuración del Gráfico ---

# Aumentamos el tamaño de la figura.
# (14, 12) suele ser bueno para este número de variables.
plt.figure(figsize=(14, 12))

# Creamos el heatmap con argumentos específicos para mejorar la visualización
sns.heatmap(
    corr_matrix,
    annot=True,       # Pone los números dentro de las celdas
    fmt=".2f",        # ¡CRUCIAL! Redondea a 2 decimales. Evita que los textos se pisen.
    cmap="RdBu_r",    # Un mapa de color divergente (Rojo=Positivo, Azul=Negativo) se lee mejor.
    center=0,         # Centra el mapa de color en 0.
    linewidths=0.5,   # Añade pequeñas líneas blancas entre celdas para separarlas.
    cbar_kws={"shrink": .8}) # Hace la barra de color lateral un poco más pequeña
    

# Ajusta los ejes para que no se corten las etiquetas si son muy largas
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       6 # --- PASO 1: Limpieza de Datos ---
#       7 # Las columnas 'id' y 'Unnamed: 0' son identificadores, no variables.
#       8 # Calcular su correlación no tiene sentido y ensucia el gráfico.
#       9 # Las eliminamos temporalmente para el gráfico.
#      10 columns_to_drop = ['Unnamed: 0', 'id']
# ---> 11 df_clean = df.drop(columns=columns_to_drop, errors='ignore')
#      13 # Calculamos la matriz de correlación sobre los datos limpios
#      14 corr_matrix = df_clean.corr(numeric_only=True)
#
# NameError: name 'df' is not defined

# %%
df =pd.read_csv("data/raw/train.csv")

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df_test =pd.read_csv("data/test.csv")

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
# ...

# %%
# 1. Recargar datos para asegurar que están limpios (Evita el error de ejecución doble)
# Asegúrate de que la ruta coincida con tu carpeta (ej. "data/train.csv" o "train.csv")
df = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# 2. Definir diccionarios
mapa_satisfaccion = {'neutral or dissatisfied': 0, 'satisfied': 1}
mapa_clase = {'Eco': 0, 'Eco Plus': 1, 'Business': 2}
mapa_viaje = {'Personal Travel': 0, 'Business travel': 1}

# 3. Aplicar limpieza y mapeo en un solo paso seguro
# Usamos un bucle para aplicar lo mismo a train y test
for dataset in [df, df_test]:
    # Limpieza de espacios (solo si es texto)
    # Convertimos a números usando map
    dataset['satisfaction'] = dataset['satisfaction'].astype(str).str.strip().map(mapa_satisfaccion)
    dataset['Class'] = dataset['Class'].astype(str).str.strip().map(mapa_clase)
    dataset['Type of Travel'] = dataset['Type of Travel'].astype(str).str.strip().map(mapa_viaje)

# 4. Verificar
print("Valores únicos en Class:", df['Class'].unique())  # Debería salir [1 2 0] o similar, NO nan
print(df.info())
# Out:
# Valores únicos en Class: [1 2 0]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  int64
#  6   Class                              103904 non-null  int64
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age  Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13               0
# 1                1    5047    Male  disloyal Customer   25               1
# 2                2  110028  Female     Loyal Customer   26               1
# 3                3   24026  Female     Loyal Customer   25               1
# 4                4  119299    Male     Loyal Customer   61               1
# ...            ...     ...     ...                ...  ...             ...
# 103899      103899   94171  Female  disloyal Customer   23               1
# 103900      103900   73097    Male     Loyal Customer   49               1
# 103901      103901   68825    Male  disloyal Customer   30               1
# 103902      103902   54173  Female  disloyal Customer   22               1
# 103903      103903   62567    Male     Loyal Customer   27               1
#
#         Class  Flight Distance  Inflight wifi service  \
# ...

# %%
df_test
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age  Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52               1
# 1               1  90035  Female     Loyal Customer   36               1
# 2               2  12360    Male  disloyal Customer   20               1
# 3               3  77959    Male     Loyal Customer   44               1
# 4               4  36875  Female     Loyal Customer   49               1
# ...           ...    ...     ...                ...  ...             ...
# 25971       25971  78463    Male  disloyal Customer   34               1
# 25972       25972  71167    Male     Loyal Customer   23               1
# 25973       25973  37675  Female     Loyal Customer   17               0
# 25974       25974  90086    Male     Loyal Customer   14               1
# 25975       25975  34799  Female     Loyal Customer   42               0
#
#        Class  Flight Distance  Inflight wifi service  \
# ...

# %%
# --- PASO 1: Limpieza de Datos ---
# Las columnas 'id' y 'Unnamed: 0' son identificadores, no variables.
# Calcular su correlación no tiene sentido y ensucia el gráfico.
# Las eliminamos temporalmente para el gráfico.
columns_to_drop = ['Unnamed: 0', 'id']
df_clean = df.drop(columns=columns_to_drop, errors='ignore')

# Calculamos la matriz de correlación sobre los datos limpios
corr_matrix = df_clean.corr(numeric_only=True)


# --- PASO 2: Configuración del Gráfico ---

# Aumentamos el tamaño de la figura.
# (14, 12) suele ser bueno para este número de variables.
plt.figure(figsize=(14, 12))

# Creamos el heatmap con argumentos específicos para mejorar la visualización
sns.heatmap(
    corr_matrix,
    annot=True,       # Pone los números dentro de las celdas
    fmt=".2f",        # ¡CRUCIAL! Redondea a 2 decimales. Evita que los textos se pisen.
    cmap="RdBu_r",    # Un mapa de color divergente (Rojo=Positivo, Azul=Negativo) se lee mejor.
    center=0,         # Centra el mapa de color en 0.
    linewidths=0.5,   # Añade pequeñas líneas blancas entre celdas para separarlas.
    cbar_kws={"shrink": .8}) # Hace la barra de color lateral un poco más pequeña
    

# Ajusta los ejes para que no se corten las etiquetas si son muy largas
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# 1. Recargar datos originales para asegurar un estado inicial limpio
df = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# 2. Definir diccionarios de mapeo y traducción
mapa_satisfaccion = {'neutral or dissatisfied': 0, 'satisfied': 1}
mapa_clase = {'Eco': 0, 'Eco Plus': 1, 'Business': 2}
mapa_viaje = {'Personal Travel': 0, 'Business travel': 1}

columnas_espanol = {
    'Gender': 'Genero',
    'Customer Type': 'Tipo_Cliente',
    'Age': 'Edad',
    'Type of Travel': 'Tipo_Viaje',
    'Class': 'Clase',
    'Flight Distance': 'Distancia_Vuelo',
    'Inflight wifi service': 'Wifi_Vuelo',
    'Departure/Arrival time convenient': 'Hora_Conveniente',
    'Ease of Online booking': 'Facilidad_Reserva_Online',
    'Gate location': 'Ubicacion_Puerta',
    'Food and drink': 'Comida_Bebida',
    'Online boarding': 'Embarque_Online',
    'Seat comfort': 'Confort_Asiento',
    'Inflight entertainment': 'Entretenimiento',
    'On-board service': 'Servicio_A_Bordo',
    'Leg room service': 'Espacio_Piernas',
    'Baggage handling': 'Manejo_Equipaje',
    'Checkin service': 'Servicio_Checkin',
    'Inflight service': 'Servicio_En_Vuelo',
    'Cleanliness': 'Limpieza',
    'Departure Delay in Minutes': 'Retraso_Salida_Min',
    'Arrival Delay in Minutes': 'Retraso_Llegada_Min',
    'satisfaction': 'Satisfaccion'}

# ---------------------------------------------------------
# 3. PROCESAR DATASET DE ENTRENAMIENTO (df)
# ---------------------------------------------------------
print("Procesando datos de entrenamiento (df)...")

# Mapeo de variables categóricas a numéricas
df['satisfaction'] = df['satisfaction'].astype(str).str.strip().map(mapa_satisfaccion)
df['Class'] = df['Class'].astype(str).str.strip().map(mapa_clase)
df['Type of Travel'] = df['Type of Travel'].astype(str).str.strip().map(mapa_viaje)

# Renombrar columnas al español
df.rename(columns=columnas_espanol, inplace=True)

# Eliminar columnas innecesarias (si existen)
if 'Unnamed: 0' in df.columns:
    df.drop(columns=['Unnamed: 0'], inplace=True)
if 'id' in df.columns:
    df.drop(columns=['id'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 4
#       1 import pandas as pd
#       3 # 1. Recargar datos originales para asegurar un estado inicial limpio
# ----> 4 df = pd.read_csv("data/train.csv")
#       5 df_test = pd.read_csv("data/test.csv")
#       7 # 2. Definir diccionarios de mapeo y traducción
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Cargar datos
df = pd.read_csv("data/train.csv") # Asegúrate que la ruta sea correcta

# 2. Mapear columnas de texto a números (necesario para el modelo y el heatmap)
# Esto es Feature Engineering básico
mapa_satisfaccion = {'neutral or dissatisfied': 0, 'satisfied': 1}
mapa_clase = {'Eco': 0, 'Eco Plus': 1, 'Business': 2}
mapa_viaje = {'Personal Travel': 0, 'Business travel': 1}

df['satisfaction'] = df['satisfaction'].map(mapa_satisfaccion)
df['Class'] = df['Class'].map(mapa_clase)
df['Type of Travel'] = df['Type of Travel'].map(mapa_viaje)
# Nota: Para 'Gender' y 'Customer Type' podrías usar pd.get_dummies más adelante

# 3. ELIMINAR COLUMNAS (La limpieza que preguntaste)
cols_a_eliminar = ['Unnamed: 0', 'id', 'Departure Delay in Minutes']
df_limpio = df.drop(columns=cols_a_eliminar, errors='ignore')

# 4. TRATAR NULOS (Arrival Delay tiene huecos)
# Rellenamos con la media para no perder datos
df_limpio['Arrival Delay in Minutes'] = df_limpio['Arrival Delay in Minutes'].fillna(df_limpio['Arrival Delay in Minutes'].mean())

# 5. Generar el Heatmap (Solo con columnas numéricas)
plt.figure(figsize=(16, 12))
sns.heatmap(
    df_limpio.corr(numeric_only=True), 
    annot=True, 
    fmt=".2f", 
    cmap="RdBu_r", 
    center=0
)
plt.title("Mapa de Correlación: ¿Qué afecta realmente a la satisfacción?")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import matplotlib.pyplot as plt
#       5 # 1. Cargar datos
# ----> 6 df = pd.read_csv("data/train.csv") # Asegúrate que la ruta sea correcta
#       8 # 2. Mapear columnas de texto a números (necesario para el modelo y el heatmap)
#       9 # Esto es Feature Engineering básico
#      10 mapa_satisfaccion = {'neutral or dissatisfied': 0, 'satisfied': 1}
#
# ...
